# %% [markdown]
# ### Graph the computation speed for each GPU.
#
# Reference: [XiongjieDai/GPU-Benchmarks-on-LLM-Inference](https://github.com/XiongjieDai/GPU-Benchmarks-on-LLM-Inference)
#
# Reference: [GPU Specs Database](https://www.techpowerup.com/gpu-specs/)

# %%
#import numpy as np
import pandas as pd
#import matplotlib.pyplot as plt

generation_speed_to_bandwidth = pd.DataFrame([
    [  8,  448.0,  70.94,           'RTX3070', 'NVIDIA'],
    [ 10,  760.3, 106.40,           'RTX3080', 'NVIDIA'],
    [ 12,  912.4, 106.72,           'RTX3080', 'NVIDIA'],
    [ 12,  504.2,  82.21,           'RTX4070', 'NVIDIA'],
    [ 16,  716.8, 106.22,           'RTX4080', 'NVIDIA'],
    [ 20,  360.0,  58.59,        'RTX4000Ada', 'NVIDIA'],
    [ 24,  936.2, 111.74,           'RTX3090', 'NVIDIA'],
    [ 24, 1010.0, 127.74,           'RTX4090', 'NVIDIA'],
    [ 32,  576.0,  89.87,        'RTX5000Ada', 'NVIDIA'],
    [ 48,  768.0, 102.22,          'RTXA6000', 'NVIDIA'],
    [ 48,  960.0, 130.99,        'RTX6000Ada', 'NVIDIA'],
    [ 48,  695.8,  88.95,               'A40', 'NVIDIA'],
    [ 48,  864.0, 113.60,              'L40S', 'NVIDIA'],
    [ 80, 1940.0, 138.31,          'A100PCIe', 'NVIDIA'],
    [ 80, 2040.0, 133.38,           'A100SXM', 'NVIDIA'],
    [ 80, 2040.0, 144.49,          'H100PCIe', 'NVIDIA'],
#M1 7‑Core GPU 8GB	9.72	OOM	OOM	OOM
#M1 Max 32‑Core GPU 64GB	34.49	18.43	4.09	OOM
#M2 Ultra 76-Core GPU 192GB	76.28	36.25	12.13	4.71
#M3 Max 40‑Core GPU 64GB	50.74	22.39	7.53
], columns=['memory', 'bandwidth', 'generation speed', 'type', 'manufacturer'])

graph = generation_speed_to_bandwidth.plot.scatter(
    x='bandwidth',
    y='generation speed'
)

for k, v in generation_speed_to_bandwidth.iterrows():
    graph.annotate(
        v[3],
        xy=(v[1], v[2]),
        size=7.5,
        xytext=(0,-10),
        textcoords='offset points'
    )
# Out:
# /var/folders/90/kskh3wbj04d1cp3_crkb9cgr0000gn/T/ipykernel_75475/2177552159.py:47: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   v[3],
# /var/folders/90/kskh3wbj04d1cp3_crkb9cgr0000gn/T/ipykernel_75475/2177552159.py:48: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   xy=(v[1], v[2]),
